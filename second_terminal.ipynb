# %% [markdown]
# Second Terminal to run No Conv 5-way, 5-shot omniglot

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/DL_MAML
# Out:
# /content/drive/MyDrive/Colab Notebooks/DL_MAML

# %%
# !ls
# Out:
# data			 logs	  __pycache__		 terminal.ipynb
# data_generator.py	 main.py  second_terminal.ipynb  utils.py
# download_datasets.ipynb  maml.py  special_grads.py

# %%
import tensorflow as tf
import torch
import os

# %%
if tf.config.list_physical_devices('GPU'):
    print("GPU is available!")
    print("GPU details:", tf.config.list_physical_devices('GPU'))
else:
    print("No GPU found.")
# Out:
# GPU is available!
# GPU details: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
if torch.cuda.is_available():
    print("GPU is available!")
    print("GPU name:", torch.cuda.get_device_name(0))
else:
    print("No GPU found.")
# Out:
# GPU is available!
# GPU name: NVIDIA A100-SXM4-80GB

# %%
# BASELINE MAML No Conv 5-way, 5-shot omniglot
# !python main.py --datasource=omniglot --metatrain_iterations=60000 --meta_batch_size=32 --update_batch_size=5 --update_lr=0.4 --num_updates=1 --logdir=logs/omniglot_5way_5shot_baseline/ --conv=False
# Out:
# 2025-12-14 04:49:40.652613: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765687780.673961    3118 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765687780.680410    3118 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765687780.696889    3118 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# Iteration 16000: 0.18375, 0.99
# Validation results: 0.185, 0.9775
# Iteration 16100: 0.185, 0.9875
# Iteration 16200: 0.15625, 0.98375

# %%
# by hour 20, will it be at 24000...?
# Actual: Hour 16: reached 26000
# Hour 20: reached 30000
# goal: 32000
# 1 hour later: 33000
# 8.5 hours later: 36000
# 11.75 hrs later: 39000
# 20 hrs later: 46500

# new goal: 49000

# 8 hrs: 52000
# 13.5 hrs: 57500
# 14.5 hrs: 58500
# goal: 60000

# %%
# Test 1
# !python main.py --datasource=omniglot --metatrain_iterations=60000 --meta_batch_size=32 --update_batch_size=5 --update_lr=0.4 --num_updates=1 --logdir=logs/omniglot_5way_5shot_baseline/ --conv=False --train=False --test_set=True
# Out:
# 2025-12-14 20:45:30.828961: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765745130.850544  245210 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765745130.857128  245210 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765745130.873741  245210 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# Test 2
# !python main.py --datasource=omniglot --metatrain_iterations=60000 --meta_batch_size=32 --update_batch_size=5 --update_lr=0.4 --num_updates=1 --logdir=logs/omniglot_5way_5shot_baseline/ --conv=False --train=False --test_set=True
# Out:
# 2025-12-14 22:34:42.627760: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765751682.649214  273603 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765751682.655736  273603 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765751682.672298  273603 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# Test 3
# !python main.py --datasource=omniglot --metatrain_iterations=60000 --meta_batch_size=32 --update_batch_size=5 --update_lr=0.4 --num_updates=1 --logdir=logs/omniglot_5way_5shot_baseline/ --conv=False --train=False --test_set=True
# Out:
# 2025-12-14 22:36:07.251254: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765751767.272709  274099 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765751767.279111  274099 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765751767.295466  274099 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
