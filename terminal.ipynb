# %% [markdown]
# Second Terminal to run 5-way, 5-shot omniglot

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/DL_MAML
# Out:
# /content/drive/MyDrive/Colab Notebooks/DL_MAML

# %%
# !ls
# Out:
# data			 logs	  __pycache__		 terminal.ipynb
# data_generator.py	 main.py  second_terminal.ipynb  utils.py
# download_datasets.ipynb  maml.py  special_grads.py

# %%
import tensorflow as tf
import torch
import os

# %%
if tf.config.list_physical_devices('GPU'):
    print("GPU is available!")
    print("GPU details:", tf.config.list_physical_devices('GPU'))
else:
    print("No GPU found.")
# Out:
# GPU is available!
# GPU details: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
if torch.cuda.is_available():
    print("GPU is available!")
    print("GPU name:", torch.cuda.get_device_name(0))
else:
    print("No GPU found.")
# Out:
# GPU is available!
# GPU name: NVIDIA A100-SXM4-80GB

# %%
# MAML 5-way, 5-shot omniglot
# !python main.py --datasource=omniglot --metatrain_iterations=60000 --meta_batch_size=32 --update_batch_size=5 --update_lr=0.4 --num_updates=1 --logdir=logs/omniglot_5way_5shot/
# Out:
# 2025-12-13 05:04:55.855247: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765602295.876822    1700 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765602295.883316    1700 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765602295.900270    1700 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# 10 hours to go from 31000 to 36000... 5000 per hour. 41000 by hour 20...?
# Actual: Hour 16: Reached 41000
# Hour 20: reached 45000
# goal: 46000

# 1 hour: 46800
# 3 hours:
# Iteration 48500: 0.17125, 0.99875
# Validation results: 0.1875, 1.0
# Iteration 48600: 0.20624998, 0.99875
# Iteration 48700: 0.205, 0.99625003
# Iteration 48800: 0.19999999, 0.9925

# 8.5 hours later: 51000
# 11 hours: 54000
# goal: 60000

# %%
# !python main.py --datasource=omniglot --metatrain_iterations=60000 --meta_batch_size=32 --update_batch_size=5 --update_lr=0.4 --num_updates=1 --logdir=logs/omniglot_5way_5shot/ --train=False --test_set=True
# Out:
# 2025-12-13 23:33:37.119350: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765668817.143200  274850 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765668817.149999  274850 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765668817.167140  274850 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python main.py --datasource=omniglot --metatrain_iterations=60000 --meta_batch_size=32 --update_batch_size=5 --update_lr=0.4 --num_updates=1 --logdir=logs/omniglot_5way_5shot/ --train=False --test_set=True
# Out:
# 2025-12-14 01:23:15.975963: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765675395.997483  302696 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765675396.003997  302696 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765675396.020412  302696 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python main.py --datasource=omniglot --metatrain_iterations=60000 --meta_batch_size=32 --update_batch_size=5 --update_lr=0.4 --num_updates=1 --logdir=logs/omniglot_5way_5shot/ --train=False --test_set=True
# Out:
# 2025-12-14 01:24:49.276509: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765675489.299113  303313 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765675489.305904  303313 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765675489.323019  303313 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
